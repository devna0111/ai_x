# %%
from PIL import Image

img=Image.open("sample_9.png")

# %%
import numpy as np

gray_img = img.convert('L')

# %%
img.show()

# %%
gray_array = np.array(gray_img)

# %%
print(gray_array.shape)
# Out:
# (28, 28)
