# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - 올라마는 특별하게 설정할 환경이 없음(api_key가 필요없음)
# - pip install langchain-ollama
# - pip install langchain-community

# %%
# %pip install langchain-community
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-community) (0.3.66)
# Collecting langchain<1.0.0,>=0.3.26 (from langchain-community)
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain-community)
#   Using cached sqlalchemy-2.0.41-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-community) (0.4.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-core<1.0.0,>=0.3.66 (from langchain-community)
#   Downloading langchain_core-0.3.72-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain<1.0.0,>=0.3.26->langchain-community)
#   Downloading langchain_text_splitters-0.3.9-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from requests<3,>=2->langchain-community) (2025.6.15)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain-community)
#   Using cached greenlet-3.2.3-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langsmith>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\anaconda3\envs\llm\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Using cached langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 9.7 MB/s eta 0:00:00
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_core-0.3.72-py3-none-any.whl (442 kB)
# Downloading langchain_text_splitters-0.3.9-py3-none-any.whl (33 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Using cached sqlalchemy-2.0.41-cp310-cp310-win_amd64.whl (2.1 MB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached greenlet-3.2.3-cp310-cp310-win_amd64.whl (296 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: mypy-extensions, marshmallow, httpx-sse, greenlet, async-timeout, typing-inspect, SQLAlchemy, pydantic-settings, dataclasses-json, langchain-core, langchain-text-splitters, langchain, langchain-community
#
#    ------ ---------------------------------  2/13 [httpx-sse]
#    --------- ------------------------------  3/13 [greenlet]
#    --------- ------------------------------  3/13 [greenlet]
#   Attempting uninstall: async-timeout
#    --------- ------------------------------  3/13 [greenlet]
#     Found existing installation: async-timeout 5.0.1
#    --------- ------------------------------  3/13 [greenlet]
#     Uninstalling async-timeout-5.0.1:
#    --------- ------------------------------  3/13 [greenlet]
#       Successfully uninstalled async-timeout-5.0.1
#    --------- ------------------------------  3/13 [greenlet]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    ------------------ ---------------------  6/13 [SQLAlchemy]
#    --------------------- ------------------  7/13 [pydantic-settings]
#    ------------------------ ---------------  8/13 [dataclasses-json]
#   Attempting uninstall: langchain-core
#    ------------------------ ---------------  8/13 [dataclasses-json]
#     Found existing installation: langchain-core 0.3.66
#    ------------------------ ---------------  8/13 [dataclasses-json]
#    --------------------------- ------------  9/13 [langchain-core]
#     Uninstalling langchain-core-0.3.66:
#    --------------------------- ------------  9/13 [langchain-core]
#       Successfully uninstalled langchain-core-0.3.66
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    --------------------------- ------------  9/13 [langchain-core]
#    ------------------------------ --------- 10/13 [langchain-text-splitters]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    --------------------------------- ------ 11/13 [langchain]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ------------------------------------ --- 12/13 [langchain-community]
#    ---------------------------------------- 13/13 [langchain-community]
#
# Successfully installed SQLAlchemy-2.0.41 async-timeout-4.0.3 dataclasses-json-0.6.7 greenlet-3.2.3 httpx-sse-0.4.1 langchain-0.3.27 langchain-community-0.3.27 langchain-core-0.3.72 langchain-text-splitters-0.3.9 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.10.1 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. LLM 답변 생성

# %%
from langchain_ollama import ChatOllama
# from langchain_community.chat_models import ChatOllama
llm = ChatOllama(model='gemma3:4b')
ai_message = llm.invoke("2020년 월드시리즈에서 누가 우승했나요?")

# %%
ai_message.content
# Out:
# '2020년 월드시리즈에서 토론토 블루제이스가 로스앤젤레스 다저스를 4:2로 꺾고 우승했습니다.'

# %% [markdown]
# # 3. colab에서 ollama(exaone3.5:2.4b) 돌리기
# - http://bit.ly/3IKpnVH
